# %%
import numpy as np

# %%
data = np.array([[1,2],[3,4],[5,6]])
type(data)
# Out:
# numpy.ndarray

# %%
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (3, 2)

# %%
data.size
# Out:
# 6

# %%
x = np.array([-1,0,1])
y = np.array([-2,0,2])
X, Y = np.meshgrid(x, y)

# %%
X
# Out:
# array([[-1,  0,  1],
#        [-1,  0,  1],
#        [-1,  0,  1]])

# %%
Y
# Out:
# array([[-2, -2, -2],
#        [ 0,  0,  0],
#        [ 2,  2,  2]])

# %%
np.empty(3, dtype=np.float)
# Out:
# array([1.07474606e-311, 0.00000000e+000, 1.46417710e-312])
