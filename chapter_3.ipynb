# %%
import sympy
sympy.int_priting()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b61ee42ed991> in <module>
#       1 import sympy
# ----> 2 sympy.int_priting()
#
# AttributeError: module 'sympy' has no attribute 'int_priting'

# %%
from sympy import I, pi, oo

# %%
x = sympy.Symbol("x")

# %%
y = sympy.Symbol("y", real=True)
y.is_real
# Out:
# True

# %%
x.is_real is None
# Out:
# True

# %%
sympy.Symbol("z", imaginary=True).is_real
# Out:
# False

# %%
x = sympy.Symbol("x")
y=sympy.Symbol("y", postivie = True)
sympy.sqrt(x**2)
# Out:
# sqrt(x**2)

# %%
sympy.sqrt(y ** 2)
# Out:
# sqrt(y**2)

# %%
n1 = sympy.Symbol("n")
n2=sympy.Symbol("n", integer=True)
n3=sympy.Symbol("n", odd=True)
sympy.cos(n1*pi)
# Out:
# cos(pi*n)

# %%
sympy.cos(n2*pi)
# Out:
# (-1)**n

# %%
sympy.cos(n3*pi)
# Out:
# -1
